# %%
import cv2
import numpy
import os

cwd = os.getcwd()
path = os.path.join(cwd, 'Data', 'lane.jpg')

# %%
def binary_image(img, threshold,):
    # convert the image pixel value into binary 0 and 1

    binary = np.ones
    return binary

# %%
class LaneDetection:
    def __init__(self,frame):
        pass

# %%
def main():
    frame = cv2.imread(path)
    Lane = LaneDetection(frame)
    cv2.imshow("sdgsg",frame)
    cv2.waitKey(0) 
    cv2.destroyAllWindows()

# %%
if __name__=="__main__":
    main()
